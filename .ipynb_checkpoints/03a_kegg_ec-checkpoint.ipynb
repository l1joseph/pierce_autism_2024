# %% [markdown]
# # Pierce - Pathway Analysis
# Author: Leo Joseph (l1joseph@ucsd.edu)
# The purpose of the notebook is to perform pathway  analysis on ASD versus TD samples.

# %%
# qiime2 imports
import qiime2 as q2
from qiime2 import Artifact, Metadata, Visualization
from qiime2.plugins.feature_table.methods import filter_features, filter_samples

# birdman imports
import biom
import pandas as pd
import numpy as np

# visualization imports
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# The history saving thread hit an unexpected error (DatabaseError('database disk image is malformed')).History will not be written to the database.

# %% [markdown]
# ## Load Artifacts

# %%
ec = biom.load_table('/home/lpatel/projects/2024-03-04_pierce-autism/out/195333_ec.zebra.tp-td.biom')
ko = biom.load_table('/home/lpatel/projects/2024-03-04_pierce-autism/out/195334_ko.zebra.tp-td.biom')
pathway = biom.load_table('/home/lpatel/projects/2024-03-04_pierce-autism/out/195331_pathway.zebra.tp-td.biom')

md = Metadata.load('/home/lpatel/projects/2024-03-04_pierce-autism/qiita/15350_20240110-175840_noblanks.txt')
info = pd.read_csv('/home/lpatel/projects/2024-03-04_pierce-autism/ref/tryptophan_kegg.tsv', sep='\t', index_col=0)

# %%
# Assuming `info` is a DataFrame that contains the "EC" column
# And `ec` is the BIOM table loaded from 'out/195333_ec.zebra.biom'

# Convert the EC column values to a set for faster lookup
ec_info_values = set(info["EC"].values)

# Get the observation IDs from the BIOM table `ec`
ec_observation_ids = set(ec.ids(axis='observation'))

# Find the overlap
overlap = ec_info_values.intersection(ec_observation_ids)

# Display the overlap
print(f"Number of overlapping items: {len(overlap)}")
print(f"Overlapping items: {overlap}")
# Out:
# Number of overlapping items: 7
# Overlapping items: {'1.13.11.11', '3.7.1.3', '3.5.1.9', '4.1.1.28', '1.13.11.6', '1.14.16.1', '1.4.3.4'}

# %%
info
# Out:
#                                                       Other Name K0/ortholog  \
# Name
# tryptophan 2,3-dioxygenase                            TDO2, kynA      K00453
# indoleamine 2,3-dioxygenase                                  IDO      K00463
# arylformamidase                                             kynB      K07130
# kynureninase                                                kynU      K01556
# CCBL                                                         NaN      K00816
# kynurenine/2-aminoadipate aminotransferase           AADAT, KAT2      K00825
# kynurenine aminotransferase                                 BNA3      K14264
# kynurenine 3-monooxygenase                                   KMO      K00486
# 3-hydroxyanthranilate 3,4-dioxygenase                       HAAO      K00452
# tryptophan 5-monooxygenase                                TPH1_2      K00502
# phenylalanine-4-hydroxylase                                  PAH      K00500
# aromatic-L-amino-acid/L-tryptophan decarboxylase  DDC, TDC, AAAD      K01593
# monoamine oxidase                                            MAO      K00274
#
#                                                           EC  \
# Name
# tryptophan 2,3-dioxygenase                        1.13.11.11
# indoleamine 2,3-dioxygenase                       1.13.11.52
# arylformamidase                                      3.5.1.9
# kynureninase                                         3.7.1.3
# CCBL                                                 2.6.1.7
# kynurenine/2-aminoadipate aminotransferase           2.6.1.7
# kynurenine aminotransferase                          2.6.1.7
# kynurenine 3-monooxygenase                         1.14.13.9
# 3-hydroxyanthranilate 3,4-dioxygenase              1.13.11.6
# tryptophan 5-monooxygenase                         1.14.16.4
# phenylalanine-4-hydroxylase                        1.14.16.1
# aromatic-L-amino-acid/L-tryptophan decarboxylase    4.1.1.28
# monoamine oxidase                                    1.4.3.4
#
#                                                  Tryptophan Pathway
# Name
# tryptophan 2,3-dioxygenase                               kynurinine
# indoleamine 2,3-dioxygenase                              kynurinine
# arylformamidase                                          kynurinine
# kynureninase                                             kynurinine
# CCBL                                                     kynurinine
# kynurenine/2-aminoadipate aminotransferase               kynurinine
# kynurenine aminotransferase                              kynurinine
# kynurenine 3-monooxygenase                               kynurinine
# 3-hydroxyanthranilate 3,4-dioxygenase                    kynurinine
# tryptophan 5-monooxygenase                                serotonin
# phenylalanine-4-hydroxylase                               serotonin
# aromatic-L-amino-acid/L-tryptophan decarboxylase          serotonin
# monoamine oxidase                                         serotonin

# %%
import biom
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import linkage, leaves_list

# Load BIOM tables from the given paths
ec = biom.load_table('/home/lpatel/projects/2024-03-04_pierce-autism/out/195333_ec.zebra.biom')

# Assuming `info` and `md` are already loaded as DataFrames
# Replace these with your actual data loading if necessary
# info = pd.read_csv('path_to_info.csv')
# md = pd.read_csv('path_to_metadata.csv')

# Convert the EC column values to a set for faster lookup
ec_info_values = set(info["EC"].values)

# Get the observation IDs from the BIOM table `ec`
ec_observation_ids = set(ec.ids(axis='observation'))

# Find the overlap
overlap = ec_info_values.intersection(ec_observation_ids)

# Filter the `ec` table to include only the overlapping observations
filtered_ec = ec.filter(overlap, axis='observation', inplace=False)

# Convert the filtered BIOM table to a DataFrame
filtered_ec_df = filtered_ec.to_dataframe(dense=True).T

# Group samples by the "dx" column from the metadata
metadata_df = md.to_dataframe()
grouped_samples = metadata_df["dx"].loc[filtered_ec_df.index]

# Sort rows by 'dx'
sorted_metadata_df = metadata_df.loc[filtered_ec_df.index].sort_values('dx')
sorted_filtered_ec_df = filtered_ec_df.loc[sorted_metadata_df.index]

# Define clusters for rows (samples) within each 'dx' group
def cluster_within_groups(df, group_labels):
    sorted_idx = []
    unique_groups = group_labels.unique()
    for group in unique_groups:
        group_idx = group_labels[group_labels == group].index
        group_data = df.loc[group_idx]
        if len(group_idx) > 1:  # Only cluster if there's more than one sample
            kmeans = KMeans(n_clusters=2, random_state=0).fit(group_data)
            sorted_idx.extend(group_idx[np.argsort(kmeans.labels_)])
        else:
            sorted_idx.extend(group_idx)
    return sorted_idx

row_clusters = cluster_within_groups(sorted_filtered_ec_df, sorted_metadata_df["dx"])

# Group columns by 'Tryptophan Pathway' and sort within each group
grouped_columns = info.set_index('EC').loc[filtered_ec_df.columns, "Tryptophan Pathway"]
unique_pathways = grouped_columns.unique()

sorted_col_idx = []
for pathway in unique_pathways:
    pathway_cols = grouped_columns[grouped_columns == pathway].index
    pathway_data = filtered_ec_df[pathway_cols]
    if len(pathway_cols) > 1:  # Only cluster if there's more than one column
        col_linkage = linkage(pathway_data.T, method='ward')
        sorted_col_idx.extend(pathway_cols[leaves_list(col_linkage)])
    else:
        sorted_col_idx.extend(pathway_cols)

# Reorder the DataFrame using .loc for label-based indexing
reordered_df = sorted_filtered_ec_df.loc[row_clusters, sorted_col_idx]

# Relabel the x-axis using the original index names from info
info_indexed = info.set_index('EC')
column_labels = info_indexed.loc[reordered_df.columns].index
reordered_df.columns = column_labels

# Map the "dx" column to colors
unique_dx = sorted_metadata_df["dx"].unique()
color_palette = sns.color_palette("hsv", len(unique_dx))
dx_colors = dict(zip(unique_dx, color_palette))
row_colors = sorted_metadata_df["dx"].map(dx_colors).loc[row_clusters]

# Generate the cluster map
sns.clustermap(reordered_df, row_cluster=False, col_cluster=False, figsize=(7, 10), row_colors=row_colors)
plt.show()

# %% [markdown]
# ### Log-Transform

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Log-transform the data to handle zeros
logged_df = np.log1p(sorted_filtered_ec_df)

# Retrieve the 'EC' values for the columns and match them to the default index in info
column_labels = info.loc[info['EC'].isin(logged_df.columns)].index

# Retrieve the 'dx' values for the rows
row_labels = metadata_df.loc[logged_df.index, 'dx']

# Ensure the order of column labels matches the logged_df columns
column_labels = [info[info['EC'] == col].index[0] for col in logged_df.columns]

# Transpose the DataFrame for the heatmap
transposed_logged_df = logged_df.T

# Retrieve the transposed labels
transposed_row_labels = column_labels  # Now the columns become rows
transposed_column_labels = row_labels  # Now the rows become columns

# Create the heatmap with annotations
plt.figure(figsize=(24, 2))  # Adjusted figure size for the transposed heatmap
sns.heatmap(transposed_logged_df, cmap="viridis", cbar=True,
            xticklabels=transposed_column_labels, yticklabels=transposed_row_labels)

plt.title("ASD vs. TD Tryptophan/Kynurenine EC Activity (Log)")
plt.xlabel("Samples")
plt.ylabel("EC")
plt.xticks(rotation=45)  # Rotate x labels for better readability
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Filter the samples to just "dx" == "ASD"
asd_samples = metadata_df[metadata_df['dx'] == 'ASD'].index
filtered_ec_df_asd = sorted_filtered_ec_df.loc[asd_samples]

# Log-transform the filtered data to handle zeros
logged_df_asd = np.log1p(filtered_ec_df_asd)

# Retrieve the 'EC' values for the columns and match them to the default index in info
column_labels = [info[info['EC'] == col].index[0] for col in logged_df_asd.columns]

# Retrieve the 'dx' values for the rows (though they should all be "ASD" now)
row_labels = metadata_df.loc[logged_df_asd.index, 'dx']

# Create the cluster map with annotations
plt.figure(figsize=(10, 8))  # Adjusted figure size for the cluster map
sns.clustermap(logged_df_asd, cmap="viridis", cbar=True,
               xticklabels=column_labels, yticklabels=row_labels, figsize=(8, 8))

plt.title("Cluster Map of Log-transformed ASD Samples")
plt.xlabel("EC")
plt.ylabel("Samples")
plt.xticks(rotation=45)  # Rotate x labels for better readability
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Filter the samples to just "dx" == "ASD"
asd_samples = metadata_df[metadata_df['dx'] == 'ASD'].index
filtered_ec_df_asd = sorted_filtered_ec_df.loc[asd_samples]

# Filter for just the specific EC values
specific_ec_values = ["3.5.1.9", "4.1.1.28"]
filtered_ec_df_asd_specific = filtered_ec_df_asd[specific_ec_values]

# Log-transform the filtered data to handle zeros
logged_df_asd_specific = np.log1p(filtered_ec_df_asd_specific)

# Retrieve the 'dx' values for the rows (though they should all be "ASD" now)
row_labels = metadata_df.loc[logged_df_asd_specific.index, 'dx']

# Create the cluster map with annotations
cluster_map = sns.clustermap(logged_df_asd_specific, cmap="viridis", cbar=True,
                             xticklabels=specific_ec_values, yticklabels=row_labels,
                             figsize=(10, 8), col_cluster=False)  

# Adjust the axes labels
cluster_map.ax_heatmap.set_xlabel("EC")
cluster_map.ax_heatmap.set_ylabel("Samples")
cluster_map.ax_heatmap.set_title("Cluster Map of ASD Samples for EC Activity over Tryptophan/Kynurenine (Logged)")

# Rotate x-axis labels for better readability
plt.setp(cluster_map.ax_heatmap.get_xticklabels(), rotation=45, ha='right', fontsize=10)

# Rotate y-axis labels for better readability
plt.setp(cluster_map.ax_heatmap.get_yticklabels(), rotation=0, fontsize=10)

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy.cluster.hierarchy import fcluster

# %%
# Filter the samples to just "dx" == "ASD"
asd_samples = metadata_df[metadata_df['dx'] == 'ASD'].index
filtered_ec_df_asd = sorted_filtered_ec_df.loc[asd_samples]

# Filter for just the specific EC values
specific_ec_values = ["3.5.1.9", "4.1.1.28"]
filtered_ec_df_asd_specific = filtered_ec_df_asd[specific_ec_values]

# Log-transform the filtered data to handle zeros
logged_df_asd_specific = np.log1p(filtered_ec_df_asd_specific)

# Retrieve the 'dx' values for the rows (though they should all be "ASD" now)
row_labels = metadata_df.loc[logged_df_asd_specific.index, 'dx']

# Create the cluster map with annotations
cluster_map = sns.clustermap(logged_df_asd_specific, cmap="viridis", cbar=True,
                             xticklabels=specific_ec_values, yticklabels=row_labels,
                             figsize=(10, 8), col_cluster=False)  # Disable column clustering

# Extract the row linkage matrix
row_linkage = cluster_map.dendrogram_row.linkage

# Extract the first level clusters
first_level_clusters = fcluster(row_linkage, t=2, criterion='maxclust')

# Select the indices of samples in the first-level cluster 2
first_level_cluster_2_indices = logged_df_asd_specific.index[first_level_clusters == 2]

# Create a new linkage matrix and cluster map for the second-level clustering within cluster 2
second_level_df = logged_df_asd_specific.loc[first_level_cluster_2_indices]

# Perform clustering on the second-level DataFrame
second_cluster_map = sns.clustermap(second_level_df, cmap="viridis", cbar=True,
                                    xticklabels=specific_ec_values, yticklabels=first_level_cluster_2_indices,
                                    figsize=(10, 8), col_cluster=False)

# Extract the second-level row clusters
second_row_linkage = second_cluster_map.dendrogram_row.linkage
second_level_clusters = fcluster(second_row_linkage, t=2, criterion='maxclust')

# Add the second-level cluster labels to the metadata for exploration
metadata_with_second_level_clusters = metadata_df.loc[second_level_df.index].copy()
metadata_with_second_level_clusters['Second_Level_Cluster'] = second_level_clusters

# Show the updated metadata
metadata_with_second_level_clusters["Second_Level_Cluster"].value_counts()
# Out:
# 1    34
# 2    26
# Name: Second_Level_Cluster, dtype: int64

# %%
# Identify all numeric columns in the metadata
numeric_columns = metadata_with_second_level_clusters.select_dtypes(include=[np.number]).columns
print(f"Numeric columns: {numeric_columns}")

from scipy.stats import mannwhitneyu

# Perform Mann-Whitney U tests for all numeric columns
for column in numeric_columns:
    cluster1 = metadata_with_second_level_clusters[metadata_with_second_level_clusters['Second_Level_Cluster'] == 1][column].dropna()
    cluster2 = metadata_with_second_level_clusters[metadata_with_second_level_clusters['Second_Level_Cluster'] == 2][column].dropna()
    
    if not cluster1.empty and not cluster2.empty:
        stat, p = mannwhitneyu(cluster1, cluster2)
        print(f'Mann-Whitney U test for {column}:')
        print(f'Statistic: {stat}, p-value: {p}\n')
    else:
        print(f'Skipping {column} due to insufficient data.\n')
# Out:
# Numeric columns: Index(['ados_cosotot', 'ados_cosototrrtot', 'ados_rrtot', 'ageatfecalsample',
#        'antibiotics_last_2weeks', 'breastfed_morethan1month',
#        'constipation_2wk', 'currently_breastfeeding', 'diarrhea_2wk',
#        'elevation', 'evergiven_formula', 'gestationalagebirth', 'host_age',
#        'host_taxid', 'latitude', 'longitude', 'probiotics_2wks',
#        'qiita_study_id', 'taxon_id', 'tube_id', 'vine_adapbehav_domstd',
#        'vine_comtotal_domstd', 'vine_dlytotal_domstd', 'vine_mtrtotal_domstd',
#        'vine_soctotal_domstd', 'Second_Level_Cluster'],
#       dtype='object')
# Mann-Whitney U test for ados_cosotot:
# Statistic: 457.0, p-value: 0.8276642876861541
#
# Mann-Whitney U test for ados_cosototrrtot:
# Statistic: 459.0, p-value: 0.804854622891995
#
# Mann-Whitney U test for ados_rrtot:
# Statistic: 470.0, p-value: 0.6747182081874283
#
# Mann-Whitney U test for ageatfecalsample:
# Statistic: 341.5, p-value: 0.134967389590239
#
# Mann-Whitney U test for antibiotics_last_2weeks:
# Statistic: 434.0, p-value: 0.795696265041511
#
# Mann-Whitney U test for breastfed_morethan1month:
# Statistic: 368.0, p-value: 0.06260861029126102
#
# Mann-Whitney U test for constipation_2wk:
# Statistic: 383.0, p-value: 0.11658410710002001
#
# Mann-Whitney U test for currently_breastfeeding:
# Statistic: 464.0, p-value: 0.4579419740423113
#
# Mann-Whitney U test for diarrhea_2wk:
# Statistic: 447.0, p-value: 0.8884948244473988
#
# Mann-Whitney U test for elevation:
# Statistic: 442.0, p-value: 1.0
#
# Mann-Whitney U test for evergiven_formula:
# Statistic: 394.0, p-value: 0.1727291065380464
#
# Mann-Whitney U test for gestationalagebirth:
# Statistic: 486.5, p-value: 0.5000010747172521
#
# Mann-Whitney U test for host_age:
# Statistic: 341.5, p-value: 0.134967389590239
#
# Mann-Whitney U test for host_taxid:
# Statistic: 442.0, p-value: 1.0
#
# Mann-Whitney U test for latitude:
# Statistic: 442.0, p-value: 1.0
#
# Mann-Whitney U test for longitude:
# Statistic: 442.0, p-value: 1.0
#
# Mann-Whitney U test for probiotics_2wks:
# Statistic: 456.0, p-value: 0.7323563052268762
#
# Mann-Whitney U test for qiita_study_id:
# Statistic: 442.0, p-value: 1.0
#
# Mann-Whitney U test for taxon_id:
# Statistic: 442.0, p-value: 1.0
#
# Mann-Whitney U test for tube_id:
# Statistic: 450.0, p-value: 0.9109168432401189
#
# Mann-Whitney U test for vine_adapbehav_domstd:
# Statistic: 440.5, p-value: 0.9880906201940673
#
# Mann-Whitney U test for vine_comtotal_domstd:
# Statistic: 414.0, p-value: 0.6810217811592391
#
# Mann-Whitney U test for vine_dlytotal_domstd:
# Statistic: 495.0, p-value: 0.43060839980818244
#
# Mann-Whitney U test for vine_mtrtotal_domstd:
# Statistic: 361.0, p-value: 0.22876480294801094
#
# Mann-Whitney U test for vine_soctotal_domstd:
# Statistic: 436.0, p-value: 0.9345658538860719
#
# Mann-Whitney U test for Second_Level_Cluster:
# Statistic: 0.0, p-value: 1.6873296912443995e-14

# %% [markdown]
# ### RCLR

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Apply RCLR transformation
def rclr_transform(df):
    # Replace zeros with a small value to allow log transformation
    epsilon = 1e-5
    df_nonzero = df.replace(0, epsilon)
    
    # Log transform
    df_log = np.log(df_nonzero)
    
    # Calculate the mean of log values for each sample
    log_mean = df_log.mean(axis=1)
    
    # Subtract the log mean from each log-transformed value
    df_centered = df_log.sub(log_mean, axis=0)
    
    # Replace -inf values (resulting from log(epsilon)) with 0
    return df_centered.replace(-np.inf, 0)

# Apply RCLR transformation to the data
rclr_df = rclr_transform(sorted_filtered_ec_df)

# Retrieve the 'EC' values for the columns and match them to the default index in info
column_labels = info.loc[info['EC'].isin(rclr_df.columns)].index

# Retrieve the 'dx' values for the rows
row_labels = metadata_df.loc[rclr_df.index, 'dx']

# Ensure the order of column labels matches the rclr_df columns
column_labels = [info[info['EC'] == col].index[0] for col in rclr_df.columns]

# Transpose the DataFrame for the heatmap
transposed_rclr_df = rclr_df.T

# Retrieve the transposed labels
transposed_row_labels = column_labels  # Now the columns become rows
transposed_column_labels = row_labels  # Now the rows become columns

# Create the heatmap with annotations
plt.figure(figsize=(24, 2))  # Adjusted figure size for the transposed heatmap
sns.heatmap(transposed_rclr_df, cmap="viridis", cbar=True,
            xticklabels=transposed_column_labels, yticklabels=transposed_row_labels)
plt.title("ASD vs. TD Tryptophan/Kynurenine EC Activity (RCLR)")
plt.xlabel("Samples")
plt.ylabel("EC")
plt.xticks(rotation=45)  # Rotate x labels for better readability
plt.show()

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd
# from gemelli.preprocessing import matrix_rclr

# # Apply RCLR transformation using gemelli's matrix_rclr function
# rclr_df = pd.DataFrame(
#     matrix_rclr(sorted_filtered_ec_df.values),
#     index=sorted_filtered_ec_df.index,
#     columns=sorted_filtered_ec_df.columns
# )

# # Retrieve the 'EC' values for the columns and match them to the default index in info
# column_labels = info.loc[info['EC'].isin(rclr_df.columns)].index

# # Retrieve the 'dx' values for the rows
# row_labels = metadata_df.loc[rclr_df.index, 'dx']

# # Ensure the order of column labels matches the rclr_df columns
# column_labels = [info[info['EC'] == col].index[0] for col in rclr_df.columns]

# # Transpose the DataFrame for the heatmap
# transposed_rclr_df = rclr_df.T

# # Retrieve the transposed labels
# transposed_row_labels = column_labels  # Now the columns become rows
# transposed_column_labels = row_labels  # Now the rows become columns

# # Create the heatmap with annotations
# plt.figure(figsize=(24, 2))  # Adjusted figure size for the transposed heatmap
# sns.heatmap(transposed_rclr_df, cmap="viridis", cbar=True,
#             xticklabels=transposed_column_labels, yticklabels=transposed_row_labels)
# plt.title("ASD vs. TD Tryptophan/Kynurenine EC Activity (RCLR)")
# plt.xlabel("Samples")
# plt.ylabel("EC")
# plt.xticks(rotation=45)  # Rotate x labels for better readability
# plt.show()

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from gemelli.preprocessing import matrix_rclr

# Apply RCLR transformation using gemelli's matrix_rclr function
rclr_df = pd.DataFrame(
    matrix_rclr(sorted_filtered_ec_df.values),
    index=sorted_filtered_ec_df.index,
    columns=sorted_filtered_ec_df.columns
)

# Replace NaN values with 0
rclr_df = rclr_df.fillna(0)

# Retrieve the 'EC' values for the columns and match them to the default index in info
column_labels = info.loc[info['EC'].isin(rclr_df.columns)].index

# Retrieve the 'dx' values for the rows
row_labels = metadata_df.loc[rclr_df.index, 'dx']

# Ensure the order of column labels matches the rclr_df columns
column_labels = [info[info['EC'] == col].index[0] for col in rclr_df.columns]

# Transpose the DataFrame for the heatmap
transposed_rclr_df = rclr_df.T

# Retrieve the transposed labels
transposed_row_labels = column_labels  # Now the columns become rows
transposed_column_labels = row_labels  # Now the rows become columns

# Create the heatmap with annotations
plt.figure(figsize=(24, 2))  # Adjusted figure size for the transposed heatmap
sns.heatmap(transposed_rclr_df, cmap="viridis", cbar=True,
            xticklabels=transposed_column_labels, yticklabels=transposed_row_labels)
plt.title("ASD vs. TD Tryptophan/Kynurenine EC Activity (RCLR)")
plt.xlabel("Samples")
plt.ylabel("EC")
plt.xticks(rotation=45)  # Rotate x labels for better readability
plt.show()

# Print some diagnostic information
print(f"Shape of the data: {rclr_df.shape}")
print(f"Number of NaN values after replacement: {rclr_df.isna().sum().sum()}")
print(f"Min value: {rclr_df.min().min()}")
print(f"Max value: {rclr_df.max().max()}")
# Out:
# Shape of the data: (83, 7)
# Number of NaN values after replacement: 0
# Min value: -3.4315502919778105
# Max value: 4.210238667681556

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from gemelli.preprocessing import matrix_rclr
from scipy.cluster.hierarchy import linkage

# Filter the samples to just "dx" == "ASD"
asd_samples = metadata_df[metadata_df['dx'] == 'ASD'].index
filtered_ec_df_asd = sorted_filtered_ec_df.loc[asd_samples]

# Remove rows and columns that are all zeros
filtered_ec_df_asd = filtered_ec_df_asd.loc[(filtered_ec_df_asd != 0).any(axis=1), (filtered_ec_df_asd != 0).any(axis=0)]

# Apply RCLR transformation using gemelli's matrix_rclr function
rclr_df_asd = pd.DataFrame(
    matrix_rclr(filtered_ec_df_asd.values),
    index=filtered_ec_df_asd.index,
    columns=filtered_ec_df_asd.columns
)

# Replace NaN and infinite values with a small epsilon
epsilon = 0
rclr_df_asd = rclr_df_asd.replace([np.inf, -np.inf], np.nan).fillna(epsilon)

# Print diagnostic information
print(f"Shape after RCLR and NaN replacement: {rclr_df_asd.shape}")
print(f"Number of samples: {rclr_df_asd.shape[0]}")
print(f"Number of ECs: {rclr_df_asd.shape[1]}")
print(f"Any remaining NaN values: {np.isnan(rclr_df_asd).any().any()}")
print(f"Any remaining infinite values: {np.isinf(rclr_df_asd).any().any()}")

# Retrieve the 'EC' values for the columns and match them to the default index in info
column_labels = [info[info['EC'] == col].index[0] for col in rclr_df_asd.columns]

# Create the cluster map
g = sns.clustermap(rclr_df_asd, 
                   cmap="viridis", 
                   cbar=True,
                   xticklabels=column_labels, 
                   yticklabels=False,  # Hide row labels for better visibility
                   figsize=(15, 10), 
                   dendrogram_ratio=(.1, .2),
                   cbar_pos=(0.02, .32, .03, .2))

# Adjust the plot
g.ax_heatmap.set_xlabel("EC")
g.ax_heatmap.set_ylabel("Samples")
g.ax_heatmap.set_xticklabels(g.ax_heatmap.get_xticklabels(), rotation=90, ha='center')
g.fig.suptitle("Cluster Map of RCLR-transformed ASD Samples", fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# Shape after RCLR and NaN replacement: (63, 7)
# Number of samples: 63
# Number of ECs: 7
# Any remaining NaN values: False
# Any remaining infinite values: False
# /tmp/ipykernel_224071/4265183712.py:51: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.cluster.hierarchy import linkage, fcluster

# Assuming rclr_df_asd is already defined from the previous code

# Drop the first three samples
rclr_df_asd_dropped = rclr_df_asd.iloc[3:]

# Perform hierarchical clustering
row_linkage = linkage(rclr_df_asd_dropped, method='ward')

# Generate two clusters at the first level
first_level_clusters = fcluster(row_linkage, t=2, criterion='maxclust')

# Create a DataFrame with sample names and their cluster assignments
first_level_cluster_df = pd.DataFrame({'Sample': rclr_df_asd_dropped.index, 'Cluster': first_level_clusters})

# Function to perform sub-clustering and print results
def analyze_sub_clusters(data, cluster_samples, level):
    if len(cluster_samples) > 1:
        sub_df = data.loc[cluster_samples]
        sub_linkage = linkage(sub_df, method='ward')
        sub_clusters = fcluster(sub_linkage, t=2, criterion='maxclust')
        sub_cluster_df = pd.DataFrame({'Sample': sub_df.index, f'Level_{level}_Cluster': sub_clusters})
        
        print(f"Level {level} clusters:")
        for sub_cluster in sub_cluster_df[f'Level_{level}_Cluster'].unique():
            print(f"  Cluster {sub_cluster} samples:")
            print("  " + ", ".join(sub_cluster_df[sub_cluster_df[f'Level_{level}_Cluster'] == sub_cluster]['Sample'].tolist()))
        print()
        
        # If we're at level 2, analyze level 3 clusters
        if level == 2:
            for sub_cluster in sub_cluster_df[f'Level_{level}_Cluster'].unique():
                sub_sub_samples = sub_cluster_df[sub_cluster_df[f'Level_{level}_Cluster'] == sub_cluster]['Sample'].tolist()
                analyze_sub_clusters(data, sub_sub_samples, 3)

# Analyze and print clusters
for cluster in first_level_cluster_df['Cluster'].unique():
    cluster_samples = first_level_cluster_df[first_level_cluster_df['Cluster'] == cluster]['Sample'].tolist()
    print(f"First-level Cluster {cluster}:")
    print("Samples: " + ", ".join(cluster_samples))
    print()
    
    analyze_sub_clusters(rclr_df_asd_dropped, cluster_samples, 2)

# Create and display the clustermap
plt.figure(figsize=(20, 15))

g = sns.clustermap(rclr_df_asd_dropped, 
                   cmap="viridis", 
                   cbar=True,
                   xticklabels=False, 
                   yticklabels=False,
                   figsize=(18, 13),
                   dendrogram_ratio=(.1, .2),
                   cbar_pos=(0.02, .2, .03, .4))

# Adjust subplot layout
plt.subplots_adjust(top=0.9, bottom=0.1, left=0.1, right=0.9, hspace=0.2, wspace=0.2)

g.ax_heatmap.set_xlabel("EC")
g.ax_heatmap.set_ylabel("Samples")
g.fig.suptitle("Cluster Map of RCLR-transformed ASD Samples (First 3 Samples Dropped)", fontsize=16, y=0.95)

# Adjust colorbar
cbar = g.ax_heatmap.collections[0].colorbar
cbar.ax.set_ylabel("RCLR Value", rotation=-90, va="bottom")

plt.tight_layout()
plt.show()
# Out:
# First-level Cluster 1:
# Samples: 15350.A7B7Z.1, 15350.A7L6P.1, 15350.A7U2D.1, 15350.A7U7E.1, 15350.A7Z3W.1, 15350.A8B6R.2, 15350.A8K2F.1, 15350.A9K5A.1, 15350.B2P8J.1, 15350.B3D2S.1, 15350.B4M6P.1, 15350.B4Q5Y.1, 15350.B4R3L.1, 15350.B5C9W.1, 15350.B6C8B.1, 15350.B9F8Y.1, 15350.B9U3M.1, 15350.C2H2Q.1, 15350.C3E7W.1, 15350.C3P8T.1, 15350.C3W3Q.1
#
# Level 2 clusters:
#   Cluster 1 samples:
#   15350.A7B7Z.1, 15350.A7U2D.1, 15350.A7U7E.1, 15350.A7Z3W.1, 15350.A8K2F.1, 15350.A9K5A.1, 15350.B2P8J.1, 15350.B3D2S.1, 15350.B4M6P.1, 15350.B4Q5Y.1, 15350.B4R3L.1, 15350.B5C9W.1, 15350.B9F8Y.1, 15350.B9U3M.1, 15350.C2H2Q.1, 15350.C3P8T.1, 15350.C3W3Q.1
#   Cluster 2 samples:
#   15350.A7L6P.1, 15350.A8B6R.2, 15350.B6C8B.1, 15350.C3E7W.1
#
# Level 3 clusters:
#   Cluster 2 samples:
#   15350.A7B7Z.1, 15350.A8K2F.1, 15350.B2P8J.1, 15350.B3D2S.1, 15350.B4M6P.1, 15350.B4Q5Y.1, 15350.B4R3L.1, 15350.B9F8Y.1, 15350.B9U3M.1
#   Cluster 1 samples:
#   15350.A7U2D.1, 15350.A7U7E.1, 15350.A7Z3W.1, 15350.A9K5A.1, 15350.B5C9W.1, 15350.C2H2Q.1, 15350.C3P8T.1, 15350.C3W3Q.1
#
# Level 3 clusters:
#   Cluster 2 samples:
#   15350.A7L6P.1, 15350.C3E7W.1
#   Cluster 1 samples:
#   15350.A8B6R.2, 15350.B6C8B.1
#
# First-level Cluster 2:
# Samples: 15350.A8C6X.2, 15350.A8P6X.1, 15350.A9K3E.1, 15350.B2G6D.2, 15350.B2S8R.1, 15350.B2U4C.1, 15350.B3K7K.1, 15350.B3X2Q.1, 15350.B3X9Y.1, 15350.B4B4Z.1, 15350.B4E5T.1, 15350.B4N6V.2, 15350.B4W6N.1, 15350.B4Z6J.1, 15350.B5L9P.1, 15350.B5M4U.1, 15350.B5Z8F.1, 15350.B6H4G.1, 15350.C2P4P.1, 15350.C2Q4J.1, 15350.C2Q5G.1, 15350.C2S2P.1, 15350.C2S8B.1, 15350.C3E6M.1, 15350.C3T4F.1, 15350.C3V4G.1, 15350.C3X7B.1, 15350.C3Z7C.1, 15350.C3Z9K.1, 15350.C4F8D.1, 15350.C4G9U.1, 15350.C4H7T.1, 15350.C6L4X.1, 15350.C6V2C.1, 15350.C6Z3P.1, 15350.C7T8B.1, 15350.C7V5J.1, 15350.D2P2Q.1, 15350.Z4R4J.1
#
# Level 2 clusters:
#   Cluster 2 samples:
#   15350.A8C6X.2, 15350.A8P6X.1, 15350.A9K3E.1, 15350.B2G6D.2, 15350.B2S8R.1, 15350.B2U4C.1, 15350.B3K7K.1, 15350.B3X9Y.1, 15350.B4B4Z.1, 15350.B4E5T.1, 15350.B4N6V.2, 15350.B4W6N.1, 15350.B4Z6J.1, 15350.B5M4U.1, 15350.B5Z8F.1, 15350.B6H4G.1, 15350.C2Q4J.1, 15350.C2Q5G.1, 15350.C2S2P.1, 15350.C2S8B.1, 15350.C3E6M.1, 15350.C3T4F.1, 15350.C3V4G.1, 15350.C3X7B.1, 15350.C4F8D.1, 15350.C4G9U.1, 15350.C4H7T.1, 15350.C6V2C.1, 15350.C6Z3P.1, 15350.C7T8B.1, 15350.C7V5J.1, 15350.D2P2Q.1, 15350.Z4R4J.1
#   Cluster 1 samples:
#   15350.B3X2Q.1, 15350.B5L9P.1, 15350.C2P4P.1, 15350.C3Z7C.1, 15350.C3Z9K.1, 15350.C6L4X.1
#
# Level 3 clusters:
#   Cluster 1 samples:
#   15350.A8C6X.2, 15350.A8P6X.1, 15350.B2S8R.1, 15350.B2U4C.1, 15350.B3K7K.1, 15350.B3X9Y.1, 15350.B4B4Z.1, 15350.B4E5T.1, 15350.B4N6V.2, 15350.B4W6N.1, 15350.B4Z6J.1, 15350.B5M4U.1, 15350.B5Z8F.1, 15350.B6H4G.1, 15350.C2Q4J.1, 15350.C2Q5G.1, 15350.C2S8B.1, 15350.C3E6M.1, 15350.C3T4F.1, 15350.C3V4G.1, 15350.C4F8D.1, 15350.C4G9U.1, 15350.C4H7T.1, 15350.C6Z3P.1, 15350.C7V5J.1, 15350.D2P2Q.1
#   Cluster 2 samples:
#   15350.A9K3E.1, 15350.B2G6D.2, 15350.C2S2P.1, 15350.C3X7B.1, 15350.C6V2C.1, 15350.C7T8B.1, 15350.Z4R4J.1
#
# Level 3 clusters:
#   Cluster 2 samples:
#   15350.B3X2Q.1, 15350.C2P4P.1
#   Cluster 1 samples:
#   15350.B5L9P.1, 15350.C3Z7C.1, 15350.C3Z9K.1, 15350.C6L4X.1

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.cluster.hierarchy import linkage, fcluster

# Assuming rclr_df_asd_dropped and first_level_cluster_df are already defined from the previous code

def analyze_third_level_clusters(data, cluster_samples):
    if len(cluster_samples) > 1:
        sub_df = data.loc[cluster_samples]
        sub_linkage = linkage(sub_df, method='ward')
        sub_clusters = fcluster(sub_linkage, t=2, criterion='maxclust')
        sub_cluster_df = pd.DataFrame({'Sample': sub_df.index, 'Level_2_Cluster': sub_clusters})
        
        for second_level_cluster in sub_cluster_df['Level_2_Cluster'].unique():
            second_level_samples = sub_cluster_df[sub_cluster_df['Level_2_Cluster'] == second_level_cluster]['Sample'].tolist()
            
            if len(second_level_samples) > 1:
                third_df = data.loc[second_level_samples]
                third_linkage = linkage(third_df, method='ward')
                third_clusters = fcluster(third_linkage, t=2, criterion='maxclust')
                third_cluster_df = pd.DataFrame({'Sample': third_df.index, 'Level_3_Cluster': third_clusters})
                
                print(f"Third-level clusters for second-level cluster {second_level_cluster}:")
                for third_level_cluster in third_cluster_df['Level_3_Cluster'].unique():
                    print(f"  Cluster {third_level_cluster} samples:")
                    print("  " + ", ".join(third_cluster_df[third_cluster_df['Level_3_Cluster'] == third_level_cluster]['Sample'].tolist()))
                print()

# Sort clusters by size (descending order)
cluster_sizes = first_level_cluster_df['Cluster'].value_counts().sort_values(ascending=False)

# Get the two largest clusters
largest_clusters = cluster_sizes.index[:2]

for i, cluster in enumerate(largest_clusters, 1):
    cluster_samples = first_level_cluster_df[first_level_cluster_df['Cluster'] == cluster]['Sample'].tolist()
    print(f"Analyzing Cluster {i} (original cluster {cluster}):")
    print(f"Number of samples: {len(cluster_samples)}")
    print("Samples: " + ", ".join(cluster_samples))
    print("\nThird-level clusters:")
    analyze_third_level_clusters(rclr_df_asd_dropped, cluster_samples)
    print("-" * 50)
# Out:
# Analyzing Cluster 1 (original cluster 2):
# Number of samples: 39
# Samples: 15350.A8C6X.2, 15350.A8P6X.1, 15350.A9K3E.1, 15350.B2G6D.2, 15350.B2S8R.1, 15350.B2U4C.1, 15350.B3K7K.1, 15350.B3X2Q.1, 15350.B3X9Y.1, 15350.B4B4Z.1, 15350.B4E5T.1, 15350.B4N6V.2, 15350.B4W6N.1, 15350.B4Z6J.1, 15350.B5L9P.1, 15350.B5M4U.1, 15350.B5Z8F.1, 15350.B6H4G.1, 15350.C2P4P.1, 15350.C2Q4J.1, 15350.C2Q5G.1, 15350.C2S2P.1, 15350.C2S8B.1, 15350.C3E6M.1, 15350.C3T4F.1, 15350.C3V4G.1, 15350.C3X7B.1, 15350.C3Z7C.1, 15350.C3Z9K.1, 15350.C4F8D.1, 15350.C4G9U.1, 15350.C4H7T.1, 15350.C6L4X.1, 15350.C6V2C.1, 15350.C6Z3P.1, 15350.C7T8B.1, 15350.C7V5J.1, 15350.D2P2Q.1, 15350.Z4R4J.1
#
# Third-level clusters:
# Third-level clusters for second-level cluster 2:
#   Cluster 1 samples:
#   15350.A8C6X.2, 15350.A8P6X.1, 15350.B2S8R.1, 15350.B2U4C.1, 15350.B3K7K.1, 15350.B3X9Y.1, 15350.B4B4Z.1, 15350.B4E5T.1, 15350.B4N6V.2, 15350.B4W6N.1, 15350.B4Z6J.1, 15350.B5M4U.1, 15350.B5Z8F.1, 15350.B6H4G.1, 15350.C2Q4J.1, 15350.C2Q5G.1, 15350.C2S8B.1, 15350.C3E6M.1, 15350.C3T4F.1, 15350.C3V4G.1, 15350.C4F8D.1, 15350.C4G9U.1, 15350.C4H7T.1, 15350.C6Z3P.1, 15350.C7V5J.1, 15350.D2P2Q.1
#   Cluster 2 samples:
#   15350.A9K3E.1, 15350.B2G6D.2, 15350.C2S2P.1, 15350.C3X7B.1, 15350.C6V2C.1, 15350.C7T8B.1, 15350.Z4R4J.1
#
# Third-level clusters for second-level cluster 1:
#   Cluster 2 samples:
#   15350.B3X2Q.1, 15350.C2P4P.1
#   Cluster 1 samples:
#   15350.B5L9P.1, 15350.C3Z7C.1, 15350.C3Z9K.1, 15350.C6L4X.1
#
# --------------------------------------------------
# Analyzing Cluster 2 (original cluster 1):
# Number of samples: 21
# Samples: 15350.A7B7Z.1, 15350.A7L6P.1, 15350.A7U2D.1, 15350.A7U7E.1, 15350.A7Z3W.1, 15350.A8B6R.2, 15350.A8K2F.1, 15350.A9K5A.1, 15350.B2P8J.1, 15350.B3D2S.1, 15350.B4M6P.1, 15350.B4Q5Y.1, 15350.B4R3L.1, 15350.B5C9W.1, 15350.B6C8B.1, 15350.B9F8Y.1, 15350.B9U3M.1, 15350.C2H2Q.1, 15350.C3E7W.1, 15350.C3P8T.1, 15350.C3W3Q.1
#
# Third-level clusters:
# Third-level clusters for second-level cluster 1:
#   Cluster 2 samples:
#   15350.A7B7Z.1, 15350.A8K2F.1, 15350.B2P8J.1, 15350.B3D2S.1, 15350.B4M6P.1, 15350.B4Q5Y.1, 15350.B4R3L.1, 15350.B9F8Y.1, 15350.B9U3M.1
#   Cluster 1 samples:
#   15350.A7U2D.1, 15350.A7U7E.1, 15350.A7Z3W.1, 15350.A9K5A.1, 15350.B5C9W.1, 15350.C2H2Q.1, 15350.C3P8T.1, 15350.C3W3Q.1
#
# Third-level clusters for second-level cluster 2:
#   Cluster 2 samples:
#   15350.A7L6P.1, 15350.C3E7W.1
#   Cluster 1 samples:
#   15350.A8B6R.2, 15350.B6C8B.1
#
# --------------------------------------------------

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Filter the samples to just "dx" == "ASD"
asd_samples = metadata_df[metadata_df['dx'] == 'ASD'].index
filtered_ec_df_asd = sorted_filtered_ec_df.loc[asd_samples]

# RCLR-transform the filtered data to handle zeros
rclr_df_asd = rclr_transform(filtered_ec_df_asd)

# Retrieve the 'EC' values for the columns and match them to the default index in info
column_labels = [info[info['EC'] == col].index[0] for col in rclr_df_asd.columns]

# Retrieve the 'dx' values for the rows (though they should all be "ASD" now)
row_labels = metadata_df.loc[rclr_df_asd.index, 'dx']

# Create the cluster map with annotations
plt.figure(figsize=(10, 8))  # Adjusted figure size for the cluster map
sns.clustermap(rclr_df_asd, cmap="viridis", cbar=True,
               xticklabels=column_labels, yticklabels=row_labels, figsize=(8, 8))

plt.title("Cluster Map of Robust Centered Log-Ratio (RCLR) transformed ASD Samples")
plt.xlabel("EC")
plt.ylabel("Samples")
plt.xticks(rotation=45)  # Rotate x labels for better readability
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Filter the samples to just "dx" == "ASD"
asd_samples = metadata_df[metadata_df['dx'] == 'ASD'].index
filtered_ec_df_asd = sorted_filtered_ec_df.loc[asd_samples]

# Filter for just the specific EC values
specific_ec_values = ["3.5.1.9", "4.1.1.28"]
filtered_ec_df_asd_specific = filtered_ec_df_asd[specific_ec_values]

# RCLR-transform the filtered data to handle zeros
rclr_df_asd_specific = rclr_transform(filtered_ec_df_asd_specific)

# Retrieve the 'dx' values for the rows (though they should all be "ASD" now)
row_labels = metadata_df.loc[rclr_df_asd_specific.index, 'dx']

# Create the cluster map with annotations
cluster_map = sns.clustermap(rclr_df_asd_specific, cmap="viridis", cbar=True,
                             xticklabels=specific_ec_values, yticklabels=row_labels,
                             figsize=(10, 8), col_cluster=False)  

# Adjust the axes labels
cluster_map.ax_heatmap.set_xlabel("EC")
cluster_map.ax_heatmap.set_ylabel("Samples")
cluster_map.ax_heatmap.set_title("Cluster Map of ASD Samples for EC Activity over Tryptophan/Kynurenine (RCLR)")

# Rotate x-axis labels for better readability
plt.setp(cluster_map.ax_heatmap.get_xticklabels(), rotation=45, ha='right', fontsize=10)

# Rotate y-axis labels for better readability
plt.setp(cluster_map.ax_heatmap.get_yticklabels(), rotation=0, fontsize=10)

# Show the plot
plt.show()

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt
# import numpy as np
# from scipy.cluster.hierarchy import fcluster, linkage

# # Filter the samples to just "dx" == "ASD"
# asd_samples = metadata_df[metadata_df['dx'] == 'ASD'].index
# filtered_ec_df_asd = sorted_filtered_ec_df.loc[asd_samples]

# # Filter for just the specific EC values
# specific_ec_values = ["3.5.1.9", "4.1.1.28"]
# filtered_ec_df_asd_specific = filtered_ec_df_asd[specific_ec_values]

# # RCLR-transform the filtered data to handle zeros
# rclr_df_asd_specific = rclr_transform(filtered_ec_df_asd_specific)

# # Retrieve the 'dx' values for the rows (though they should all be "ASD" now)
# row_labels = metadata_df.loc[rclr_df_asd_specific.index, 'dx']

# # Check if we have enough data for clustering
# if rclr_df_asd_specific.shape[0] > 1:
#     # Create the cluster map with annotations
#     cluster_map = sns.clustermap(rclr_df_asd_specific, cmap="viridis", cbar=True,
#                                  xticklabels=specific_ec_values, yticklabels=row_labels,
#                                  figsize=(10, 8), col_cluster=False)  # Disable column clustering

#     # Extract the row linkage matrix
#     row_linkage = cluster_map.dendrogram_row.linkage

#     # Extract the first level clusters
#     first_level_clusters = fcluster(row_linkage, t=2, criterion='maxclust')

#     # Select the indices of samples in the first-level cluster 2
#     first_level_cluster_2_indices = rclr_df_asd_specific.index[first_level_clusters == 2]

#     # Check if we have enough data for second-level clustering
#     if len(first_level_cluster_2_indices) > 1:
#         # Create a new DataFrame for the second-level clustering within cluster 2
#         second_level_df = rclr_df_asd_specific.loc[first_level_cluster_2_indices]

#         # Perform clustering on the second-level DataFrame
#         second_cluster_map = sns.clustermap(second_level_df, cmap="viridis", cbar=True,
#                                             xticklabels=specific_ec_values, yticklabels=first_level_cluster_2_indices,
#                                             figsize=(10, 8), col_cluster=False)

#         # Extract the second-level row clusters
#         second_row_linkage = second_cluster_map.dendrogram_row.linkage
#         second_level_clusters = fcluster(second_row_linkage, t=2, criterion='maxclust')

#         # Add the second-level cluster labels to the metadata for exploration
#         metadata_with_second_level_clusters = metadata_df.loc[second_level_df.index].copy()
#         metadata_with_second_level_clusters['Second_Level_Cluster'] = second_level_clusters

#         # Show the updated metadata
#         print(metadata_with_second_level_clusters["Second_Level_Cluster"].value_counts())
#     else:
#         print("Not enough data in the second level for clustering (less than 2 samples).")
# else:
#     print("Not enough data for clustering (less than 2 samples).")

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt
# import numpy as np
# from scipy.cluster.hierarchy import fcluster, dendrogram, linkage
# import pandas as pd

# # Filter the samples to just "dx" == "ASD"
# asd_samples = metadata_df[metadata_df['dx'] == 'ASD'].index
# filtered_ec_df_asd = sorted_filtered_ec_df.loc[asd_samples]

# # Filter for just the specific EC values
# specific_ec_values = ["3.5.1.9", "4.1.1.28"]
# filtered_ec_df_asd_specific = filtered_ec_df_asd[specific_ec_values]

# # RCLR-transform the filtered data to handle zeros
# rclr_df_asd_specific = rclr_transform(filtered_ec_df_asd_specific)

# # Create the cluster map with annotations
# cluster_map = sns.clustermap(rclr_df_asd_specific, cmap="viridis", cbar=True,
#                              xticklabels=specific_ec_values, yticklabels=rclr_df_asd_specific.index,
#                              figsize=(12, 10), col_cluster=False)

# # Extract the row linkage matrix
# row_linkage = cluster_map.dendrogram_row.linkage

# # Extract the first level clusters
# first_level_clusters = fcluster(row_linkage, t=2, criterion='maxclust')

# # Create a df with cluster assignments
# cluster_df = pd.DataFrame({'Sample': rclr_df_asd_specific.index, 'Cluster': first_level_clusters})

# for cluster in cluster_df['Cluster'].unique():
#     print(f"Cluster {cluster} samples:")
#     print(cluster_df[cluster_df['Cluster'] == cluster]['Sample'].tolist())
#     print()

# # annotate w/ sample IDs
# for i, sample in enumerate(rclr_df_asd_specific.index):
#     cluster_map.ax_heatmap.text(2.05, i, sample, ha='left', va='center')

# plt.title("Cluster Map of ASD Samples for EC Activity over Tryptophan/Kynurenine (RCLR)")
# plt.tight_layout()
# plt.show()

# # Select the indices of samples in the first-level cluster 2 (assuming it's the smaller cluster)
# first_level_cluster_2_indices = cluster_df[cluster_df['Cluster'] == 2]['Sample'].tolist()

# # check if enough data for second-level clustering
# if len(first_level_cluster_2_indices) > 1:
#     # create a new df for the second-level clustering within cluster 2
#     second_level_df = rclr_df_asd_specific.loc[first_level_cluster_2_indices]
    
#     # perform clustering on the second-level df
#     second_cluster_map = sns.clustermap(second_level_df, cmap="viridis", cbar=True,
#                                         xticklabels=specific_ec_values, yticklabels=second_level_df.index,
#                                         figsize=(10, 8), col_cluster=False)
    
#     # extract the second-level row clusters
#     second_row_linkage = second_cluster_map.dendrogram_row.linkage
#     second_level_clusters = fcluster(second_row_linkage, t=2, criterion='maxclust')
    
#     # add the second-level cluster labels to the metadata for exploration
#     metadata_with_second_level_clusters = metadata_df.loc[second_level_df.index].copy()
#     metadata_with_second_level_clusters['Second_Level_Cluster'] = second_level_clusters
    
#     print("Second-level clusters:")
#     print(metadata_with_second_level_clusters["Second_Level_Cluster"].value_counts())
    
#     for cluster in metadata_with_second_level_clusters['Second_Level_Cluster'].unique():
#         print(f"Second-level Cluster {cluster} samples:")
#         print(metadata_with_second_level_clusters[metadata_with_second_level_clusters['Second_Level_Cluster'] == cluster].index.tolist())
#         print()
# else:
#     print("Not enough data in the second level for clustering (less than 2 samples).")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy.cluster.hierarchy import fcluster, dendrogram, linkage
import pandas as pd

# Assuming we have already performed RCLR transformation and have rclr_df_asd_specific

# Create the cluster map with annotations
cluster_map = sns.clustermap(rclr_df_asd_specific, cmap="viridis", cbar=True,
                             xticklabels=specific_ec_values, yticklabels=rclr_df_asd_specific.index,
                             figsize=(15, 10), col_cluster=False)

# Extract the row linkage matrix
row_linkage = cluster_map.dendrogram_row.linkage

# Function to get clusters at a specific level
def get_clusters_at_level(linkage_matrix, n_clusters):
    return fcluster(linkage_matrix, t=n_clusters, criterion='maxclust')

# Get second-level clusters
second_level_clusters = get_clusters_at_level(row_linkage, n_clusters=2)

# Create a DataFrame with cluster assignments
cluster_df = pd.DataFrame({
    'Sample': rclr_df_asd_specific.index,
    'Second_Level_Cluster': second_level_clusters
})

# Print samples in each second-level cluster
for cluster in cluster_df['Second_Level_Cluster'].unique():
    print(f"Second-level Cluster {cluster} samples:")
    print(cluster_df[cluster_df['Second_Level_Cluster'] == cluster]['Sample'].tolist())
    print()

# Annotate the plot with sample IDs and second-level cluster information
for i, (sample, cluster) in enumerate(zip(rclr_df_asd_specific.index, second_level_clusters)):
    cluster_map.ax_heatmap.text(2.05, i, f"{sample} (C{cluster})", ha='left', va='center', fontsize=8)

plt.title("Cluster Map of ASD Samples for EC Activity over Tryptophan/Kynurenine (RCLR)")
plt.tight_layout()
plt.show()

# Add the second-level cluster labels to the metadata for exploration
metadata_with_second_level_clusters = metadata_df.loc[rclr_df_asd_specific.index].copy()
metadata_with_second_level_clusters['Second_Level_Cluster'] = second_level_clusters

# Show the updated metadata
print("Second-level cluster distribution:")
print(metadata_with_second_level_clusters["Second_Level_Cluster"].value_counts())

# Optional: Perform further analysis on each second-level cluster
for cluster in metadata_with_second_level_clusters['Second_Level_Cluster'].unique():
    cluster_samples = metadata_with_second_level_clusters[metadata_with_second_level_clusters['Second_Level_Cluster'] == cluster]
    print(f"\nAnalysis for Second-level Cluster {cluster}:")
    print(f"Number of samples: {len(cluster_samples)}")
    print("EC activity statistics:")
    print(rclr_df_asd_specific.loc[cluster_samples.index].describe())
    print("\n")
# Out:
# Second-level Cluster 1 samples:
# ['15350.A5U7C.2', '15350.A6N5R.1', '15350.A6T5B.1', '15350.A7B7Z.1', '15350.A7L6P.1', '15350.A7U2D.1', '15350.A7U7E.1', '15350.A7Z3W.1', '15350.A8B6R.2', '15350.A8C6X.2', '15350.A8K2F.1', '15350.A8P6X.1', '15350.A9K3E.1', '15350.A9K5A.1', '15350.B2G6D.2', '15350.B2P8J.1', '15350.B2S8R.1', '15350.B2U4C.1', '15350.B3D2S.1', '15350.B3K7K.1', '15350.B3X2Q.1', '15350.B3X9Y.1', '15350.B4B4Z.1', '15350.B4E5T.1', '15350.B4M6P.1', '15350.B4N6V.2', '15350.B4Q5Y.1', '15350.B4R3L.1', '15350.B4W6N.1', '15350.B4Z6J.1', '15350.B5C9W.1', '15350.B5L9P.1', '15350.B5M4U.1', '15350.B5Z8F.1', '15350.B6C8B.1', '15350.B6H4G.1', '15350.B9F8Y.1', '15350.B9U3M.1', '15350.C2H2Q.1', '15350.C2P4P.1', '15350.C2Q4J.1', '15350.C2Q5G.1', '15350.C2S2P.1', '15350.C2S8B.1', '15350.C3E6M.1', '15350.C3E7W.1', '15350.C3P8T.1', '15350.C3T4F.1', '15350.C3V4G.1', '15350.C3W3Q.1', '15350.C3X7B.1', '15350.C3Z7C.1', '15350.C3Z9K.1', '15350.C4F8D.1', '15350.C4G9U.1', '15350.C4H7T.1', '15350.C6L4X.1', '15350.C6Z3P.1', '15350.C7T8B.1', '15350.C7V5J.1', '15350.D2P2Q.1', '15350.Z4R4J.1']
#
# Second-level Cluster 2 samples:
# ['15350.C6V2C.1']
# Second-level cluster distribution:
# 1    62
# 2     1
# Name: Second_Level_Cluster, dtype: int64
#
# Analysis for Second-level Cluster 1:
# Number of samples: 62
# EC activity statistics:
#          3.5.1.9   4.1.1.28
# count  62.000000  62.000000
# mean    3.358295  -3.358295
# std     3.185469   3.185469
# min    -0.346574  -8.598253
# 25%     0.997828  -7.328798
# 50%     1.674875  -1.674875
# 75%     7.328798  -0.997828
# max     8.598253   0.346574
#
#
#
# Analysis for Second-level Cluster 2:
# Number of samples: 1
# EC activity statistics:
#         3.5.1.9  4.1.1.28
# count  1.000000  1.000000
# mean  -6.561182  6.561182
# std         NaN       NaN
# min   -6.561182  6.561182
# 25%   -6.561182  6.561182
# 50%   -6.561182  6.561182
# 75%   -6.561182  6.561182
# max   -6.561182  6.561182

# %%
cluster_map = sns.clustermap(rclr_df_asd_specific, cmap="viridis", cbar=True,
                             xticklabels=specific_ec_values, yticklabels=rclr_df_asd_specific.index,
                             figsize=(12, 10), col_cluster=False)

row_linkage = cluster_map.dendrogram_row.linkage

first_level_clusters = fcluster(row_linkage, t=2, criterion='maxclust')

first_level_cluster_df = pd.DataFrame({'Sample': rclr_df_asd_specific.index, 'Cluster': first_level_clusters})

for cluster in first_level_cluster_df['Cluster'].unique():
    print(f"Cluster {cluster} samples:")
    print(first_level_cluster_df[first_level_cluster_df['Cluster'] == cluster]['Sample'].tolist())
    print()

for first_level_cluster in first_level_cluster_df['Cluster'].unique():
    cluster_samples = first_level_cluster_df[first_level_cluster_df['Cluster'] == first_level_cluster]['Sample'].tolist()
    
    if len(cluster_samples) > 1:
        second_level_df = rclr_df_asd_specific.loc[cluster_samples]
        second_cluster_map = sns.clustermap(second_level_df, cmap="viridis", cbar=True,
                                            xticklabels=specific_ec_values, yticklabels=second_level_df.index,
                                            figsize=(10, 8), col_cluster=False)
        second_row_linkage = second_cluster_map.dendrogram_row.linkage
        second_level_clusters = fcluster(second_row_linkage, t=2, criterion='maxclust')
        second_level_cluster_df = pd.DataFrame({'Sample': second_level_df.index, 'Second_Level_Cluster': second_level_clusters})
        
        print(f"First-level Cluster {first_level_cluster} second-level clusters:")
        for second_level_cluster in second_level_cluster_df['Second_Level_Cluster'].unique():
            print(f"Second-level Cluster {second_level_cluster} samples:")
            print(second_level_cluster_df[second_level_cluster_df['Second_Level_Cluster'] == second_level_cluster]['Sample'].tolist())
            print()
# Out:
# Cluster 1 samples:
# ['15350.A5U7C.2', '15350.A6N5R.1', '15350.A6T5B.1', '15350.A7B7Z.1', '15350.A7L6P.1', '15350.A7U2D.1', '15350.A7U7E.1', '15350.A7Z3W.1', '15350.A8B6R.2', '15350.A8C6X.2', '15350.A8K2F.1', '15350.A8P6X.1', '15350.A9K3E.1', '15350.A9K5A.1', '15350.B2G6D.2', '15350.B2P8J.1', '15350.B2S8R.1', '15350.B2U4C.1', '15350.B3D2S.1', '15350.B3K7K.1', '15350.B3X2Q.1', '15350.B3X9Y.1', '15350.B4B4Z.1', '15350.B4E5T.1', '15350.B4M6P.1', '15350.B4N6V.2', '15350.B4Q5Y.1', '15350.B4R3L.1', '15350.B4W6N.1', '15350.B4Z6J.1', '15350.B5C9W.1', '15350.B5L9P.1', '15350.B5M4U.1', '15350.B5Z8F.1', '15350.B6C8B.1', '15350.B6H4G.1', '15350.B9F8Y.1', '15350.B9U3M.1', '15350.C2H2Q.1', '15350.C2P4P.1', '15350.C2Q4J.1', '15350.C2Q5G.1', '15350.C2S2P.1', '15350.C2S8B.1', '15350.C3E6M.1', '15350.C3E7W.1', '15350.C3P8T.1', '15350.C3T4F.1', '15350.C3V4G.1', '15350.C3W3Q.1', '15350.C3X7B.1', '15350.C3Z7C.1', '15350.C3Z9K.1', '15350.C4F8D.1', '15350.C4G9U.1', '15350.C4H7T.1', '15350.C6L4X.1', '15350.C6Z3P.1', '15350.C7T8B.1', '15350.C7V5J.1', '15350.D2P2Q.1', '15350.Z4R4J.1']
#
# Cluster 2 samples:
# ['15350.C6V2C.1']
#
# First-level Cluster 1 second-level clusters:
# Second-level Cluster 1 samples:
# ['15350.A5U7C.2', '15350.A6N5R.1', '15350.A6T5B.1', '15350.A7L6P.1', '15350.A8C6X.2', '15350.A8P6X.1', '15350.A9K3E.1', '15350.B2G6D.2', '15350.B2S8R.1', '15350.B2U4C.1', '15350.B3K7K.1', '15350.B3X2Q.1', '15350.B3X9Y.1', '15350.B4B4Z.1', '15350.B4E5T.1', '15350.B4N6V.2', '15350.B4W6N.1', '15350.B4Z6J.1', '15350.B5L9P.1', '15350.B5M4U.1', '15350.B5Z8F.1', '15350.B6H4G.1', '15350.C2P4P.1', '15350.C2Q4J.1', '15350.C2Q5G.1', '15350.C2S2P.1', '15350.C2S8B.1', '15350.C3E6M.1', '15350.C3T4F.1', '15350.C3V4G.1', '15350.C3X7B.1', '15350.C3Z7C.1', '15350.C3Z9K.1', '15350.C4F8D.1', '15350.C4G9U.1', '15350.C4H7T.1', '15350.C6L4X.1', '15350.C6Z3P.1', '15350.C7T8B.1', '15350.C7V5J.1', '15350.D2P2Q.1', '15350.Z4R4J.1']
#
# Second-level Cluster 2 samples:
# ['15350.A7B7Z.1', '15350.A7U2D.1', '15350.A7U7E.1', '15350.A7Z3W.1', '15350.A8B6R.2', '15350.A8K2F.1', '15350.A9K5A.1', '15350.B2P8J.1', '15350.B3D2S.1', '15350.B4M6P.1', '15350.B4Q5Y.1', '15350.B4R3L.1', '15350.B5C9W.1', '15350.B6C8B.1', '15350.B9F8Y.1', '15350.B9U3M.1', '15350.C2H2Q.1', '15350.C3E7W.1', '15350.C3P8T.1', '15350.C3W3Q.1']

# %%
cluster_map = sns.clustermap(rclr_df_asd_specific, cmap="viridis", cbar=True,
                             xticklabels=specific_ec_values, yticklabels=rclr_df_asd_specific.index,
                             figsize=(12, 10), col_cluster=False)

row_linkage = cluster_map.dendrogram_row.linkage

first_level_clusters = fcluster(row_linkage, t=2, criterion='maxclust')

first_level_cluster_df = pd.DataFrame({'Sample': rclr_df_asd_specific.index, 'Cluster': first_level_clusters})

for cluster in first_level_cluster_df['Cluster'].unique():
    print(f"Cluster {cluster} samples:")
    print(first_level_cluster_df[first_level_cluster_df['Cluster'] == cluster]['Sample'].tolist())
    print()

for first_level_cluster in first_level_cluster_df['Cluster'].unique():
    cluster_samples = first_level_cluster_df[first_level_cluster_df['Cluster'] == first_level_cluster]['Sample'].tolist()
    
    if len(cluster_samples) > 1:
        second_level_df = rclr_df_asd_specific.loc[cluster_samples]
        second_cluster_map = sns.clustermap(second_level_df, cmap="viridis", cbar=True,
                                            xticklabels=specific_ec_values, yticklabels=second_level_df.index,
                                            figsize=(10, 8), col_cluster=False)
        second_row_linkage = second_cluster_map.dendrogram_row.linkage
        second_level_clusters = fcluster(second_row_linkage, t=2, criterion='maxclust')
        second_level_cluster_df = pd.DataFrame({'Sample': second_level_df.index, 'Second_Level_Cluster': second_level_clusters})
        
        print(f"First-level Cluster {first_level_cluster} second-level clusters:")
        for second_level_cluster in second_level_cluster_df['Second_Level_Cluster'].unique():
            print(f"Second-level Cluster {second_level_cluster} samples:")
            print(second_level_cluster_df[second_level_cluster_df['Second_Level_Cluster'] == second_level_cluster]['Sample'].tolist())
            print()
# Out:
# Cluster 1 samples:
# ['15350.A5U7C.2', '15350.A6N5R.1', '15350.A6T5B.1', '15350.A7B7Z.1', '15350.A7L6P.1', '15350.A7U2D.1', '15350.A7U7E.1', '15350.A7Z3W.1', '15350.A8B6R.2', '15350.A8C6X.2', '15350.A8K2F.1', '15350.A8P6X.1', '15350.A9K3E.1', '15350.A9K5A.1', '15350.B2G6D.2', '15350.B2P8J.1', '15350.B2S8R.1', '15350.B2U4C.1', '15350.B3D2S.1', '15350.B3K7K.1', '15350.B3X2Q.1', '15350.B3X9Y.1', '15350.B4B4Z.1', '15350.B4E5T.1', '15350.B4M6P.1', '15350.B4N6V.2', '15350.B4Q5Y.1', '15350.B4R3L.1', '15350.B4W6N.1', '15350.B4Z6J.1', '15350.B5C9W.1', '15350.B5L9P.1', '15350.B5M4U.1', '15350.B5Z8F.1', '15350.B6C8B.1', '15350.B6H4G.1', '15350.B9F8Y.1', '15350.B9U3M.1', '15350.C2H2Q.1', '15350.C2P4P.1', '15350.C2Q4J.1', '15350.C2Q5G.1', '15350.C2S2P.1', '15350.C2S8B.1', '15350.C3E6M.1', '15350.C3E7W.1', '15350.C3P8T.1', '15350.C3T4F.1', '15350.C3V4G.1', '15350.C3W3Q.1', '15350.C3X7B.1', '15350.C3Z7C.1', '15350.C3Z9K.1', '15350.C4F8D.1', '15350.C4G9U.1', '15350.C4H7T.1', '15350.C6L4X.1', '15350.C6Z3P.1', '15350.C7T8B.1', '15350.C7V5J.1', '15350.D2P2Q.1', '15350.Z4R4J.1']
#
# Cluster 2 samples:
# ['15350.C6V2C.1']
#
# First-level Cluster 1 second-level clusters:
# Second-level Cluster 1 samples:
# ['15350.A5U7C.2', '15350.A6N5R.1', '15350.A6T5B.1', '15350.A7L6P.1', '15350.A8C6X.2', '15350.A8P6X.1', '15350.A9K3E.1', '15350.B2G6D.2', '15350.B2S8R.1', '15350.B2U4C.1', '15350.B3K7K.1', '15350.B3X2Q.1', '15350.B3X9Y.1', '15350.B4B4Z.1', '15350.B4E5T.1', '15350.B4N6V.2', '15350.B4W6N.1', '15350.B4Z6J.1', '15350.B5L9P.1', '15350.B5M4U.1', '15350.B5Z8F.1', '15350.B6H4G.1', '15350.C2P4P.1', '15350.C2Q4J.1', '15350.C2Q5G.1', '15350.C2S2P.1', '15350.C2S8B.1', '15350.C3E6M.1', '15350.C3T4F.1', '15350.C3V4G.1', '15350.C3X7B.1', '15350.C3Z7C.1', '15350.C3Z9K.1', '15350.C4F8D.1', '15350.C4G9U.1', '15350.C4H7T.1', '15350.C6L4X.1', '15350.C6Z3P.1', '15350.C7T8B.1', '15350.C7V5J.1', '15350.D2P2Q.1', '15350.Z4R4J.1']
#
# Second-level Cluster 2 samples:
# ['15350.A7B7Z.1', '15350.A7U2D.1', '15350.A7U7E.1', '15350.A7Z3W.1', '15350.A8B6R.2', '15350.A8K2F.1', '15350.A9K5A.1', '15350.B2P8J.1', '15350.B3D2S.1', '15350.B4M6P.1', '15350.B4Q5Y.1', '15350.B4R3L.1', '15350.B5C9W.1', '15350.B6C8B.1', '15350.B9F8Y.1', '15350.B9U3M.1', '15350.C2H2Q.1', '15350.C3E7W.1', '15350.C3P8T.1', '15350.C3W3Q.1']

# %%
# Calculate the count and proportion of 'breastfed_morethan1month' for each cluster
summary_stats_breastfed = metadata_with_second_level_clusters.groupby('Second_Level_Cluster')['breastfed_morethan1month'].agg(['sum', 'count', 'mean'])
print(summary_stats_breastfed)

import seaborn as sns
import matplotlib.pyplot as plt

# Create a bar plot for the 'breastfed_morethan1month' column
plt.figure(figsize=(8, 6))
sns.countplot(x='Second_Level_Cluster', hue='breastfed_morethan1month', data=metadata_with_second_level_clusters)
plt.title('Count of Breastfed More Than 1 Month by Cluster')
plt.xlabel('Second Level Cluster')
plt.ylabel('Count')
plt.show()

from scipy.stats import fisher_exact

# Create a contingency table
contingency_table = pd.crosstab(metadata_with_second_level_clusters['Second_Level_Cluster'],
                                metadata_with_second_level_clusters['breastfed_morethan1month'])

print('Contingency Table:')
print(contingency_table)

# Perform Fisher's Exact Test
oddsratio, p_value = fisher_exact(contingency_table)
print(f"Fisher's Exact Test for breastfed_morethan1month:")
print(f'Odds Ratio: {oddsratio}, p-value: {p_value}')
# Out:
#                        sum  count      mean
# Second_Level_Cluster
# 1                     27.0     34  0.794118
# 2                     25.0     26  0.961538
# Contingency Table:
# breastfed_morethan1month  0.0  1.0
# Second_Level_Cluster
# 1                           7   27
# 2                           1   25
# Fisher's Exact Test for breastfed_morethan1month:
# Odds Ratio: 6.481481481481482, p-value: 0.12159391478732365

# %%
metadata_with_second_level_clusters['breastfed_morethan1month']
# Out:
# sample_name
# 15350.A5U7C.2    1.0
# 15350.A6N5R.1    1.0
# 15350.A6T5B.1    1.0
# 15350.A7B7Z.1    1.0
# 15350.A7L6P.1    1.0
# 15350.A7U2D.1    0.0
# 15350.A7U7E.1    1.0
# 15350.A7Z3W.1    1.0
# 15350.A8B6R.2    1.0
# 15350.A8C6X.2    1.0
# 15350.A8K2F.1    1.0
# 15350.A8P6X.1    1.0
# 15350.A9K3E.1    1.0
# 15350.A9K5A.1    1.0
# 15350.B2G6D.2    1.0
# 15350.B2P8J.1    1.0
# 15350.B2S8R.1    1.0
# 15350.B2U4C.1    1.0
# 15350.B3D2S.1    1.0
# 15350.B3K7K.1    1.0
# 15350.B3X2Q.1    1.0
# 15350.B3X9Y.1    1.0
# 15350.B4B4Z.1    1.0
# 15350.B4E5T.1    1.0
# 15350.B4M6P.1    1.0
# 15350.B4N6V.2    1.0
# 15350.B4R3L.1    1.0
# 15350.B4W6N.1    1.0
# 15350.B4Z6J.1    1.0
# 15350.B5C9W.1    1.0
# 15350.B5L9P.1    1.0
# 15350.B5M4U.1    1.0
# 15350.B5Z8F.1    1.0
# 15350.B6C8B.1    0.0
# 15350.B6H4G.1    1.0
# 15350.B9F8Y.1    1.0
# 15350.B9U3M.1    1.0
# 15350.C2H2Q.1    1.0
# 15350.C2P4P.1    1.0
# 15350.C2Q4J.1    0.0
# 15350.C2Q5G.1    1.0
# 15350.C2S2P.1    1.0
# 15350.C2S8B.1    0.0
# 15350.C3E6M.1    1.0
# 15350.C3E7W.1    1.0
# 15350.C3P8T.1    0.0
# 15350.C3T4F.1    1.0
# 15350.C3W3Q.1    0.0
# 15350.C3X7B.1    1.0
# 15350.C3Z7C.1    1.0
# 15350.C3Z9K.1    0.0
# 15350.C4F8D.1    1.0
# 15350.C4G9U.1    0.0
# 15350.C4H7T.1    1.0
# 15350.C6L4X.1    1.0
# 15350.C6Z3P.1    1.0
# 15350.C7T8B.1    1.0
# 15350.C7V5J.1    1.0
# 15350.D2P2Q.1    1.0
# 15350.Z4R4J.1    1.0
# Name: breastfed_morethan1month, dtype: float64

# %% [markdown]
# ## PCA

# %%
import biom
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
# Load BIOM table
ec = biom.load_table('/home/lpatel/projects/2024-03-04_pierce-autism/out/195333_ec.zebra.tp-td.biom')

# Convert the BIOM table to a DataFrame
ec_df = ec.to_dataframe(dense=True).T

# Load and prepare metadata
metadata_df = md.to_dataframe()
metadata_df = metadata_df.loc[ec_df.index]

# Ensure we only have ASD and TD samples
metadata_df = metadata_df[metadata_df['dx'].isin(['ASD', 'TD'])]
ec_df = ec_df.loc[metadata_df.index]

# Normalize the data
scaler = StandardScaler()
ec_df_scaled = pd.DataFrame(scaler.fit_transform(ec_df), index=ec_df.index, columns=ec_df.columns)

# Perform PCA for visualization
pca = PCA(n_components=2)
pca_result = pca.fit_transform(ec_df_scaled)
pca_df = pd.DataFrame(data=pca_result, columns=['PC1', 'PC2'], index=ec_df_scaled.index)

# Perform K-means clustering
kmeans = KMeans(n_clusters=2, random_state=0)
cluster_labels = kmeans.fit_predict(ec_df_scaled)

# Add cluster labels and diagnosis to PCA results
pca_df['Cluster'] = cluster_labels
pca_df['Diagnosis'] = metadata_df['dx']

# Visualize the results
plt.figure(figsize=(10, 8))
sns.scatterplot(data=pca_df, x='PC1', y='PC2', hue='Diagnosis', style='Cluster', s=100)
plt.title('PCA of EC Data with K-means Clustering')
plt.show()

# Calculate the percentage of ASD and TD samples in each cluster
cluster_diagnosis = pd.crosstab(pca_df['Cluster'], pca_df['Diagnosis'], normalize='index') * 100
print("Percentage of ASD and TD samples in each cluster:")
print(cluster_diagnosis)

# Perform statistical test (chi-square) to check if the distribution is significant
from scipy.stats import chi2_contingency
contingency_table = pd.crosstab(pca_df['Cluster'], pca_df['Diagnosis'])
chi2, p_value, dof, expected = chi2_contingency(contingency_table)
print(f"\nChi-square test p-value: {p_value}")

# Identify top contributing pathways
feature_importance = pd.DataFrame({
    'ec': ec_df_scaled.columns,
    'importance': np.abs(pca.components_[0]) + np.abs(pca.components_[1])
})
top_pathways = feature_importance.sort_values('importance', ascending=False).head(10)
print("\nTop 10 contributing EC's:")
print(top_pathways)
# Out:
# Percentage of ASD and TD samples in each cluster:
# Diagnosis         ASD         TD
# Cluster
# 0           58.333333  41.666667
# 1          100.000000   0.000000
#
# Chi-square test p-value: 1.0
#
# Top 10 contributing EC's:
#               ec  importance
# 819      2.3.2.5    0.066374
# 1624  3.4.21.102    0.065730
# 400      1.2.7.3    0.064748
# 398     1.2.7.11    0.064318
# 1416    3.1.3.15    0.063870
# 56     1.1.1.290    0.063836
# 946    2.4.99.17    0.063574
# 734    2.3.1.129    0.063181
# 565      1.8.1.8    0.062756
# 1434     3.1.3.7    0.062742

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# Assuming Cluster 0 is ASD and Cluster 1 is TD
# Convert diagnoses to binary (ASD: 1, TD: 0)
true_labels = (pca_df['Diagnosis'] == 'ASD').astype(int)
# Convert cluster labels to match (Cluster 0: 1, Cluster 1: 0)
predicted_labels = 1 - pca_df['Cluster']

# Calculate metrics
precision = precision_score(true_labels, predicted_labels)
recall = recall_score(true_labels, predicted_labels)
f1 = f1_score(true_labels, predicted_labels)
accuracy = accuracy_score(true_labels, predicted_labels)

print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Precision: 0.5833
# Recall: 0.9655
# F1 Score: 0.7273
# Accuracy: 0.5714

# %%
# Load BIOM table
ec = biom.load_table('/home/lpatel/projects/2024-03-04_pierce-autism/out/195333_ec.zebra.tp-td.biom')

# Convert the BIOM table to a DataFrame
ec_df = ec.to_dataframe(dense=True).T

# Load and prepare metadata
metadata_df = md.to_dataframe()
metadata_df = metadata_df.loc[ec_df.index]

# Ensure we only have ASD and TD samples
metadata_df = metadata_df[metadata_df['dx'].isin(['ASD', 'TD'])]
ec_df = ec_df.loc[metadata_df.index]

# Log transform the data
# Adding a small constant to avoid log(0)
ec_df_log = np.log1p(ec_df)


# Perform PCA for visualization
pca = PCA(n_components=2)
pca_result = pca.fit_transform(ec_df_log)
pca_df = pd.DataFrame(data=pca_result, columns=['PC1', 'PC2'], index=ec_df_log.index)

# Perform K-means clustering
kmeans = KMeans(n_clusters=2, random_state=0)
cluster_labels = kmeans.fit_predict(ec_df_log)

# Add cluster labels and diagnosis to PCA results
pca_df['Cluster'] = cluster_labels
pca_df['Diagnosis'] = metadata_df['dx']

# Visualize the results
plt.figure(figsize=(10, 8))
sns.scatterplot(data=pca_df, x='PC1', y='PC2', hue='Diagnosis', style='Cluster', s=100)
plt.title('PCA of EC Data with K-means Clustering')
plt.show()

# Calculate the percentage of ASD and TD samples in each cluster
cluster_diagnosis = pd.crosstab(pca_df['Cluster'], pca_df['Diagnosis'], normalize='index') * 100
print("Percentage of ASD and TD samples in each cluster:")
print(cluster_diagnosis)

# Perform statistical test (chi-square) to check if the distribution is significant
from scipy.stats import chi2_contingency
contingency_table = pd.crosstab(pca_df['Cluster'], pca_df['Diagnosis'])
chi2, p_value, dof, expected = chi2_contingency(contingency_table)
print(f"\nChi-square test p-value: {p_value}")

# Identify top contributing pathways
feature_importance = pd.DataFrame({
    'ec': ec_df_log.columns,
    'importance': np.abs(pca.components_[0]) + np.abs(pca.components_[1])
})
top_pathways = feature_importance.sort_values('importance', ascending=False).head(10)
print("\nTop 10 contributing EC's:")
print(top_pathways)
# Out:
# Percentage of ASD and TD samples in each cluster:
# Diagnosis   ASD    TD
# Cluster
# 0          80.0  20.0
# 1          50.0  50.0
#
# Chi-square test p-value: 0.09815337721623904
#
# Top 10 contributing EC's:
#              ec  importance
# 1656  3.4.24.55    0.092401
# 122    1.1.1.57    0.091603
# 132    1.1.1.79    0.090674
# 134    1.1.1.81    0.090674
# 534     1.6.1.1    0.089088
# 2305   6.2.1.72    0.088784
# 1368   3.1.11.-    0.088556
# 545    1.7.1.15    0.088429
# 2114    5.1.2.3    0.088160
# 2195    5.3.3.8    0.087598

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# Assuming Cluster 0 is ASD and Cluster 1 is TD
# Convert diagnoses to binary (ASD: 1, TD: 0)
true_labels = (pca_df['Diagnosis'] == 'ASD').astype(int)
# Convert cluster labels to match (Cluster 0: 1, Cluster 1: 0)
predicted_labels = 1 - pca_df['Cluster']

# Calculate metrics
precision = precision_score(true_labels, predicted_labels)
recall = recall_score(true_labels, predicted_labels)
f1 = f1_score(true_labels, predicted_labels)
accuracy = accuracy_score(true_labels, predicted_labels)

print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Precision: 0.8000
# Recall: 0.4138
# F1 Score: 0.5455
# Accuracy: 0.5918

# %%
pca_df.to_csv('/home/l1joseph/pierce_autism_2024/data/kegg/kegg_ec_pca.tsv', sep='\t', index =True)
pca_df.head()
# Out:
#                      PC1        PC2  Cluster Diagnosis
# 15350.A9K3E.1  -3.316413   8.500307        1       ASD
# 15350.C3P5B.1 -51.953860   7.277424        1        TD
# 15350.C3V4G.1 -60.746981  45.528795        1       ASD
# 15350.C3Z7C.1  65.432709   2.654398        0       ASD
# 15350.C4H7T.1 -41.884780  15.906081        1       ASD

# %%
from scipy import stats

def analyze_pc1_metadata(pca_df, metadata_df):
    # Merge PCA results with metadata
    merged_df = pd.merge(pca_df, metadata_df, left_index=True, right_index=True)
    
    # Analyze categorical variables
    categorical_vars = ['dx', 'gender', 'antibiotics_last_2weeks', 'attend_daycare', 'breastfed_morethan1month', 'complexsocial_truepositive', 'constipation_2wk', 'csectionbirth', 'currently_breastfeeding', 
                        'diarrhea_2wk', 'dx_compsocial', 'dx_geopref', 'dx_mtrtechno', 'dx_mtrtraffic', 'dx_outdoorplay', 'geopref_truepositive', 'mtrtechno_truepositive', 'mtrtraffic_truepositive', 'outdoorplay_truepositive', 'pets_at_home', 'probiotics_2wks', 'mullen_fmt', 'mullen_rlt', 'mullen_vrt']  # Add other categorical variables as needed
    for var in categorical_vars:
        plt.figure(figsize=(10, 6))
        sns.boxplot(x=var, y='PC1', data=merged_df)
        plt.title(f'PC1 vs {var}')
        plt.show()
        
        # Perform statistical test (ANOVA for categorical variables)
        groups = [group for _, group in merged_df.groupby(var)['PC1']]
        f_value, p_value = stats.f_oneway(*groups)
        print(f"ANOVA results for {var}:")
        print(f"F-value: {f_value}, p-value: {p_value}")
        print()
    
    # Analyze continuous variables
    continuous_vars = ['mullen_elc', 'mullen_elt', 'mullen_fmt', 'mullen_rlt', 'mullen_vrt', 'outdoorplay_percentfixationsocial', 'vine_adapbehav_domstd', 'vine_comtotal_domstd', 'vine_dlytotal_domstd', 'vine_mtrtotal_domstd', 'vine_soctotal_domstd']  # Add other continuous variables as needed
    for var in continuous_vars:
        plt.figure(figsize=(10, 6))
        sns.scatterplot(x=var, y='PC1', data=merged_df, hue='dx')
        plt.title(f'PC1 vs {var}')
        plt.show()
        
        # Perform correlation analysis
        correlation, p_value = stats.pearsonr(merged_df[var], merged_df['PC1'])
        print(f"Correlation between PC1 and {var}:")
        print(f"Correlation coefficient: {correlation}, p-value: {p_value}")
        print()

# Call the function
analyze_pc1_metadata(pca_df, metadata_df)
# Out:
# ANOVA results for dx:
# F-value: 4.869410779702815, p-value: 0.03225832869468151
# ANOVA results for gender:
# F-value: 0.5232737705450297, p-value: 0.47303343825293187
# ANOVA results for antibiotics_last_2weeks:
# F-value: 2.019660593946948, p-value: 0.16187516281967332
# ANOVA results for attend_daycare:
# F-value: 3.163043367754821, p-value: 0.05163096273935942
# ANOVA results for breastfed_morethan1month:
# F-value: 0.34978736061668664, p-value: 0.5570675695459981
# ANOVA results for complexsocial_truepositive:
# F-value: 1.7606602799816933, p-value: 0.18331969723088684
# ANOVA results for constipation_2wk:
# F-value: 0.23150955900517395, p-value: 0.6326393084062911
# ANOVA results for csectionbirth:
# F-value: 0.8292845009082475, p-value: 0.4427791612446125
# ANOVA results for currently_breastfeeding:
# F-value: 0.23378223585879032, p-value: 0.6309784765221333
# ANOVA results for diarrhea_2wk:
# F-value: 0.37238317002763743, p-value: 0.5446475898523355
# ANOVA results for dx_compsocial:
# F-value: 2.097649893188498, p-value: 0.11385891176863293
# ANOVA results for dx_geopref:
# F-value: 2.0272401588226567, p-value: 0.12353872303250613
# ANOVA results for dx_mtrtechno:
# F-value: 1.8864824738779415, p-value: 0.14543352679789695
# ANOVA results for dx_mtrtraffic:
# F-value: 1.166803932538358, p-value: 0.33291592757847704
# ANOVA results for dx_outdoorplay:
# F-value: 1.974266464076812, p-value: 0.13136224684265713
# ANOVA results for geopref_truepositive:
# F-value: 0.15420724964247826, p-value: 0.8575355912863726
# ANOVA results for mtrtechno_truepositive:
# F-value: 2.763719201167107, p-value: 0.07354335095716481
# ANOVA results for mtrtraffic_truepositive:
# F-value: 0.8132061332504269, p-value: 0.4497065233164316
# ANOVA results for outdoorplay_truepositive:
# F-value: 2.088198646026647, p-value: 0.13550090468017714
# ANOVA results for pets_at_home:
# F-value: 0.36896741198819377, p-value: 0.6934756247271869
# ANOVA results for probiotics_2wks:
# F-value: 0.45770530214459204, p-value: 0.5020144329134635
# ANOVA results for mullen_fmt:
# F-value: 0.8924585858756442, p-value: 0.5830812394826195
# ANOVA results for mullen_rlt:
# F-value: 1.0783959830843144, p-value: 0.4156692075423272
# ANOVA results for mullen_vrt:
# F-value: 1.0095342715757738, p-value: 0.48172504305838826
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [26], line 38
#      35         print()
#      37 # Call the function
# ---> 38 analyze_pc1_metadata(pca_df, metadata_df)
#
# Cell In [26], line 32, in analyze_pc1_metadata(pca_df, metadata_df)
#      29 plt.show()
#      31 # Perform correlation analysis
# ---> 32 correlation, p_value = stats.pearsonr(merged_df[var], merged_df['PC1'])
#      33 print(f"Correlation between PC1 and {var}:")
#      34 print(f"Correlation coefficient: {correlation}, p-value: {p_value}")
#
# File ~/miniforge3/envs/qiime2-2022.8/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4074, in pearsonr(x, y)
#    4069     return np.nan, np.nan
#    4071 # dtype is the data type for the calculations.  This expression ensures
#    4072 # that the data type is at least 64 bit floating point.  It might have
#    4073 # more precision if the input is, for example, np.longdouble.
# -> 4074 dtype = type(1.0 + x[0] + y[0])
#    4076 if n == 2:
#    4077     return dtype(np.sign(x[1] - x[0])*np.sign(y[1] - y[0])), 1.0
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
# Identify samples diagnosed as TD but clustered as 1
td_clustered_as_1 = pca_df[(pca_df['Diagnosis'] == 'TD') & (pca_df['Cluster'] == 1)]

# Display the results
print("Samples diagnosed as TD but clustered as 1:")
print(td_clustered_as_1)

# Get the count of such samples
count_td_clustered_as_1 = len(td_clustered_as_1)
print(f"\nNumber of TD samples clustered as 1: {count_td_clustered_as_1}")

# Calculate the percentage of TD samples that were clustered as 1
total_td_samples = len(pca_df[pca_df['Diagnosis'] == 'TD'])
percentage_td_clustered_as_1 = (count_td_clustered_as_1 / total_td_samples) * 100

print(f"\nPercentage of TD samples clustered as 1: {percentage_td_clustered_as_1:.2f}%")
# Out:
# Samples diagnosed as TD but clustered as 1:
#                      PC1        PC2  Cluster Diagnosis
# 15350.C3P5B.1 -51.953860   7.277418        1        TD
# 15350.B4K6B.1 -39.251680  -7.723518        1        TD
# 15350.B4L3P.1 -20.285620  -6.816702        1        TD
# 15350.C3Q6S.1 -49.826959  14.389451        1        TD
# 15350.B5A9V.1   0.555088   3.673788        1        TD
# 15350.C2Z9J.1 -36.997379   2.666838        1        TD
# 15350.B2S3Q.1 -27.873384 -25.799234        1        TD
# 15350.C4X8Y.1 -32.828357  13.217883        1        TD
# 15350.C2P5A.1   3.198085 -18.027919        1        TD
# 15350.C3Z6R.1 -29.438353 -19.172119        1        TD
# 15350.A9F8Q.2 -12.935407 -18.226604        1        TD
# 15350.C3Y8F.1 -20.863038 -23.089057        1        TD
# 15350.C3R3G.1  -7.832359 -19.144698        1        TD
# 15350.C2Y2F.2  12.152118 -18.575247        1        TD
# 15350.B9F2B.1 -25.674464 -19.307897        1        TD
# 15350.C3N5T.1 -45.696163  -8.782518        1        TD
# 15350.C3H4A.1 -22.459679  17.230437        1        TD
#
# Number of TD samples clustered as 1: 17
#
# Percentage of TD samples clustered as 1: 85.00%
